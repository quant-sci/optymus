# %%
import sys
sys.path.append('../')

import warnings
warnings.filterwarnings('ignore')

import numpy as np

from utils.linear_search import constant_step, golden_section, bisection
from utils.plots import plot_golden_section


def func(x):
    return x[0]**2 - 3*x[0]*x[1] + 4*x[1]**2 + x[0] - x[1]  

# constant step
constant_st = constant_step(function=func,initial_point=np.array([1,2]), direction=np.array([-1,-2]))


# golden section
l_bound = np.array([10, 10])
u_bound = np.array([-10, -10])

golden_sec = golden_section(function=func, initial_point=np.array([1,2]), direction=np.array([-1,-2]))

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z = func([X, Y])

plot_golden_section(X, Y, Z, golden_sec)
