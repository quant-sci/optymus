# %%
import sys

sys.path.append('../src')

# %% [markdown]
# # Comparing the Optimization Methods

# %%
# import libraries
import jax.numpy as jnp
import numpy as np
from optymus.benchmark import methods_comparison
from optymus.benchmark import HimmeblauFunction

# %%
# define the objective function
f = HimmeblauFunction()

# define the initial point
initial_point = jnp.array([0, 5])

f.plot()

# %%
comparison = methods_comparison(f, initial_point, verbose=False, max_iter=100)
# Out:
# 100%|██████████| 11/11 [01:13<00:00,  6.68s/it]

# %%
comparison['results']
# Out:
#                                    method  \
# 0                                    BFGS
# 1                              Univariant
# 2                        Gradient Descent
# 3   Conjugate Gradients (fletcher_reeves)
# 4                                  Powell
# 5                          Newton-Raphson
# 6                                    Adam
# 7                                 Adagrad
# 8                                  Adamax
# 9                                 RMSprop
# 10                                   Yogi
#
#                                            x_opt                   f_min  \
# 0       [-2.8051181454077057, 3.131313798010024]   6.588583976279607e-11
# 1      [-2.8051180976907424, 3.1313125184240542]    3.74326772617301e-15
# 2       [-2.8051180808608414, 3.131312517644538]  1.2151348386129352e-15
# 3      [-2.8051180908358573, 3.1313124657578117]  1.1158273896131452e-13
# 4       [-2.8051181469023305, 3.131312584887037]  2.9009608415117576e-13
# 5        [2.999999999996896, 2.0000000000133182]   2.545076537982263e-21
# 6        [-2.793052990299834, 3.140203199556635]    0.008040011808338025
# 7      [-1.9076663457910115, 3.6954353270806095]       35.98393817255608
# 8       [-2.822263741759333, 3.1272400512420284]    0.010357710402059517
# 9   [-0.09997346539296385, -0.09990007036924864]      173.25400825979125
# 10     [-1.0154588800168631, 4.1608946545268575]      120.17736216526826
#
#    n_iter      time
# 0       4  0.144851
# 1       3  0.148700
# 2       5  0.158697
# 3       3  0.176412
# 4       2  0.312718
# 5       5  0.645445
# 6     100  1.093831
# 7     100  1.128459
# 8     100  1.143309
# 9     100  1.166920
# 10    100  1.167878

# %%
from optymus.plots import plot_optim

plot_optim(f_obj=f, x0=initial_point, comparison=comparison)
