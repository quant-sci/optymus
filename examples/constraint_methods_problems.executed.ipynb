# %% [markdown]
# # Constraint Methods Examples
#
# This notebook solves the three problems using penalty and barrier methods via `optymus.Optimizer`.
# Barrier runs require a strictly feasible starting point (all `g(x) < 0`).

# %%
import jax.numpy as jnp

from optymus import Optimizer


def print_result(label, result, g_cons=None, h_cons=None):
    xopt = result["xopt"]
    fmin = result["fmin"]
    print(label)
    print(f"  xopt = {xopt}")
    print(f"  fmin = {fmin}")
    if g_cons:
        vals = [g(xopt) for g in g_cons]
        print(f"  g(x) = {vals}")
    if h_cons:
        vals = [h(xopt) for h in h_cons]
        print(f"  h(x) = {vals}")
    if result.get("warnings"):
        print(f"  warnings = {result["warnings"]}")

# %% [markdown]
# ## Problem 1
#
# Minimize: `f(x1, x2) = (x1 - 2)^2 + (x2 - 2)^2`
# Subject to: `x1 + x2 + 3 <= 0`
#
# Parameters:
# - Penalty: `r_p0 = 0.1`, `beta = 10`, `x0 = {-5, -2}`
# - Barrier: `r_b0 = 10`, `beta = 0.1`, `x0 = {-5, -2}`

# %%
def f1(x):
    return (x[0] - 2.0) ** 2 + (x[1] - 2.0) ** 2

def g1(x):
    return x[0] + x[1] + 3.0

x0_penalty = jnp.array([-5.0, -2.0])
x0_barrier = jnp.array([-5.0, -2.0])

opt_penalty = Optimizer(
    f_obj=f1,
    g_cons=[g1],
    x0=x0_penalty,
    method="bfgs",
    constraint_method="penalty",
    constraint_jit=True,
    penalty_r0=0.1,
    penalty_factor=10.0,
    max_outer_iter=6,
    max_iter=200,
    learning_rate=0.00001,
    verbose=False,
)
print_result("Problem 1 - Penalty", opt_penalty.get_results(), g_cons=[g1])

opt_barrier = Optimizer(
    f_obj=f1,
    g_cons=[g1],
    x0=x0_barrier,
    method="bfgs",
    constraint_method="barrier",
    constraint_jit=True,
    barrier_r0=10.0,
    barrier_factor=0.1,
    penalty_r0=0.1,
    penalty_factor=10.0,
    max_outer_iter=6,
    max_iter=200,
    learning_rate=0.00001,
    verbose=False,
)
print_result("Problem 1 - Barrier", opt_barrier.get_results(), g_cons=[g1])
# Out:
# Problem 1 - Penalty
#   xopt = [-1.49965004 -1.49965003]
#   fmin = 24.495100734901943
#   g(x) = [Array(0.00069993, dtype=float64)]
#   warnings = ['max_outer_iter_reached']
# Problem 1 - Barrier
#   xopt = [-1.48258705 -1.48258708]
#   fmin = 24.25682532610488
#   g(x) = [Array(0.03482587, dtype=float64)]
#   warnings = ['max_outer_iter_reached']

# %% [markdown]
# ## Problem 2
#
# Minimize: `f(x1, x2) = (x1 - 2)^4 + (x1 - 2 x2)^2`
# Subject to: `x1^2 - x2 <= 0`
#
# Parameters:
# - Penalty: `r_p0 = 1`, `beta = 10`, `x0 = {3, 2}`
# - Barrier: `r_b0 = 10`, `beta = 0.1`, `x0 = {0, 1}`

# %%
def f2(x):
    return (x[0] - 2.0) ** 4 + (x[0] - 2.0 * x[1]) ** 2

def g2(x):
    return x[0] ** 2 - x[1]

x0_penalty = jnp.array([3.0, 2.0])
x0_barrier = jnp.array([0.0, 1.0])

opt_penalty = Optimizer(
    f_obj=f2,
    g_cons=[g2],
    x0=x0_penalty,
    method="bfgs",
    constraint_method="penalty",
    constraint_jit=True,
    penalty_r0=1.0,
    penalty_factor=10.0,
    max_outer_iter=6,
    max_iter=200,
    learning_rate=0.00001,
    verbose=False,
)
print_result("Problem 2 - Penalty", opt_penalty.get_results(), g_cons=[g2])

opt_barrier = Optimizer(
    f_obj=f2,
    g_cons=[g2],
    x0=x0_barrier,
    method="bfgs",
    constraint_method="barrier",
    constraint_jit=True,
    barrier_r0=10.0,
    barrier_factor=0.1,
    penalty_r0=1.0,
    penalty_factor=10.0,
    max_outer_iter=6,
    max_iter=200,
    learning_rate=0.00001,
    verbose=False,
)
print_result("Problem 2 - Barrier", opt_barrier.get_results(), g_cons=[g2])
# Out:
# Problem 2 - Penalty
#   xopt = [0.94559353 0.89411343]
#   fmin = 1.9460701274599366
#   g(x) = [Array(3.36980546e-05, dtype=float64)]
#   warnings = ['max_outer_iter_reached']
# Problem 2 - Barrier
#   xopt = [0.95076363 0.88746802]
#   fmin = 1.891234295354621
#   g(x) = [Array(0.01648345, dtype=float64)]
#   warnings = ['no_progress_warning', 'max_outer_iter_reached']

# %% [markdown]
# ## Problem 3
#
# Two-bar truss weight minimization. Variables are the mean diameter `d` and height `H`.
# Constraints: axial stress must not exceed yield and Euler buckling stress.
#
# Parameters:
# - Penalty: `r_p0 = 1e-7`, `beta = 10`, `x0 = {1, 15}`
# - Barrier: `r_b0 = 1e7`, `beta = 0.1`, `x0 = {4, 25}`

# %%
rho = 0.3
B = 30.0
P = 33e3
t = 0.1
E = 3e7
sigma_y = 1e5

def truss_geometry(x):
    d = x[0]
    H = x[1]
    L = jnp.sqrt(B**2 + H**2)
    return d, H, L

def area(d):
    return jnp.pi * d * t

def inertia(d):
    return jnp.pi * d**3 * t / 8.0

def axial_force(H, L):
    return P * L / H

def truss_stresses(x):
    d, H, L = truss_geometry(x)
    A = area(d)
    I = inertia(d)
    N = axial_force(H, L)
    axial = N / A
    euler = (jnp.pi**2 * E * I) / (L**2 * A)
    return d, L, axial, euler

def f3(x):
    d, L, _, _ = truss_stresses(x)
    return 2.0 * rho * area(d) * L

def g3_constraints(x):
    _, _, axial, euler = truss_stresses(x)
    return jnp.array([axial - sigma_y, axial - euler])

x0_penalty = jnp.array([1.0, 15.0])
x0_barrier = jnp.array([4.0, 25.0])
bounds = (jnp.array([0.1, 0.1]), jnp.array([50.0, 50.0]))

opt_penalty = Optimizer(
    f_obj=f3,
    g_cons=[g3_constraints],
    x0=x0_penalty,
    method="adam",
    constraint_method="penalty",
    penalty_r0=1e-7,
    penalty_factor=10.0,
    max_outer_iter=8,
    max_iter=300,
    learning_rate=0.05,
    bounds=bounds,
    verbose=False,
)
print_result("Problem 3 - Penalty", opt_penalty.get_results(), g_cons=[g3_constraints])

opt_barrier = Optimizer(
    f_obj=f3,
    g_cons=[g3_constraints],
    x0=x0_barrier,
    method="adam",
    constraint_method="barrier",
    barrier_r0=1e7,
    barrier_factor=0.1,
    penalty_r0=1e-7,
    penalty_factor=10.0,
    max_outer_iter=8,
    max_iter=300,
    learning_rate=0.05,
    bounds=bounds,
    verbose=False,
)
print_result("Problem 3 - Barrier", opt_barrier.get_results(), g_cons=[g3_constraints])
# Out:
# Problem 3 - Penalty
#   xopt = [ 1.8801839  20.20814515]
#   fmin = 12.819367476395902
#   g(x) = [Array(0.55938839, dtype=float64), Array(0.24084263, dtype=float64)]
#   warnings = ['max_outer_iter_reached']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 66
#      49 opt_penalty = Optimizer(
#      50     f_obj=f3,
#      51     g_cons=[g3_yield, g3_euler],
#    (...)
#      62     verbose=False,
#      63 )
#      64 print_result("Problem 3 - Penalty", opt_penalty.get_results(), g_cons=[g3_yield, g3_euler])
# ---> 66 opt_barrier = Optimizer(
#      67     f_obj=f3,
#      68     g_cons=[g3_yield, g3_euler],
#      69     x0=x0_barrier,
#      70     method="univariate",
#      71     constraint_method="barrier",
#      72     constraint_jit=True,
#      73     barrier_r0=1e7,
#      74     barrier_factor=0.1,
#      75     penalty_r0=1e-7,
#      76     penalty_factor=10.0,
#      77     max_outer_iter=4,
#      78     max_iter=50,
#      79     learning_rate=0.001,
#      80     bounds=bounds,
#      81     verbose=False,
#      82 )
#      83 print_result("Problem 3 - Barrier", opt_barrier.get_results(), g_cons=[g3_yield, g3_euler])
#
# File ~/optymus/optymus/src/optymus/optimizer/_optimizer.py:141, in Optimizer.__init__(self, f_obj, f_cons, x0, method, constraint_method, g_cons, h_cons, **kwargs)
#     122         self.opt = run_penalty_method(
#     123             f_obj=self.f_obj,
#     124             g_cons=g_cons,
#    (...)
#     138             inner_kwargs=inner_kwargs,
#     139         )
#     140     else:
# --> 141         self.opt = run_barrier_method(
#     142             f_obj=self.f_obj,
#     143             g_cons=g_cons,
#     144             h_cons=h_cons,
#     145             x0=self.x0,
#     146             inner_method=METHODS[self.method],
#     147             constraint_jit=constraint_jit,
#     148             barrier_type=barrier_type,
#     149             barrier_r0=barrier_r0,
#     150             barrier_factor=barrier_factor,
#     151             penalty_r0=penalty_r0,
#     152             penalty_factor=penalty_factor,
#     153             max_outer_iter=max_outer_iter,
#     154             constraint_tol=constraint_tol,
#     155             outer_tol=outer_tol,
#     156             barrier_eps=barrier_eps,
#     157             infeasible_penalty=infeasible_penalty,
#     158             warn_constraint_size=warn_constraint_size,
#     159             warn_slow_iter_s=warn_slow_iter_s,
#     160             warn_no_progress_iters=warn_no_progress_iters,
#     161             warn_no_progress_tol=warn_no_progress_tol,
#     162             inner_kwargs=inner_kwargs,
#     163         )
#     164     self.f_cons = g_cons
#     165 else:
#     166     # Run the optimization and store results
#
# File ~/optymus/optymus/src/optymus/optimizer/utils/constraints.py:309, in run_barrier_method(f_obj, g_cons, h_cons, x0, inner_method, constraint_jit, barrier_type, barrier_r0, barrier_factor, penalty_r0, penalty_factor, max_outer_iter, constraint_tol, outer_tol, barrier_eps, infeasible_penalty, warn_constraint_size, warn_slow_iter_s, warn_no_progress_iters, warn_no_progress_tol, inner_kwargs)
#     306     return f_obj(x_local) + penalty_scale * penalty_term + rb * barrier_term
#     308 barrier_eval = jax.jit(barrier_obj) if constraint_jit else barrier_obj
# --> 309 result = inner_method(f_obj=barrier_eval, f_cons=None, x0=x, **inner_kwargs)
#     310 iter_time = time.time() - iter_start
#     311 if warn_slow_iter_s is not None and iter_time > warn_slow_iter_s:
#
# File ~/optymus/optymus/src/optymus/methods/zero_order/_univariate.py:102, in univariate(**kwargs)
#     100 def univariate(**kwargs):
#     101     optimizer = Univariate(**kwargs)
# --> 102     return optimizer.optimize()
#
# File ~/optymus/optymus/src/optymus/methods/zero_order/_univariate.py:82, in Univariate.optimize(self)
#      80 for i in range(n):
#      81     v = u[i]
# ---> 82     r = line_search(f=self.penalized_obj, x=x, d=v, learning_rate=self.learning_rate)
#      83     x = r["xopt"]
#      84     alphas.append(r["alpha"])
#
# File ~/optymus/optymus/src/optymus/search/_search.py:183, in line_search(f, x, d, learning_rate)
#     182 def line_search(f, x, d, learning_rate=0.01):
# --> 183     a, b = bracket_minimum(func=f, x0=x, dir=d, learning_rate=learning_rate)
#     184     alpha = golden(lambda alpha: f(x + alpha * d), brack=(a, b), tol=1e-5)["xmin"]
#     185     x_opt = x + alpha * d
#
# File ~/optymus/optymus/src/optymus/search/_search.py:10, in bracket_minimum(func, x0, dir, alpha, learning_rate, eps)
#       8 eps = jnp.array(eps)
#       9 while True:
# ---> 10     alpha = alpha + learning_rate
#      11     f = func(x0 + alpha * dir)
#      12     f_prev = func(x0 + (alpha - eps) * dir)
#
# File ~/optymus/optymus/.venv/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:583, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     581 args = (other, self) if swap else (self, other)
#     582 if isinstance(other, _accepted_binop_types):
# --> 583   return binary_op(*args)
#     584 # Note: don't use isinstance here, because we don't want to raise for
#     585 # subclasses, e.g. NamedTuple objects that may override operators.
#     586 if type(other) in _rejected_binop_types:
#
# File ~/optymus/optymus/.venv/lib/python3.12/site-packages/jax/_src/numpy/ufunc_api.py:182, in ufunc.__call__(self, out, where, *args)
#     180   raise NotImplementedError(f"where argument of {self}")
#     181 call = self.__static_props['call'] or self._call_vectorized
# --> 182 return call(*args)
#
# KeyboardInterrupt:
