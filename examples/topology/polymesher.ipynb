# %% [markdown]
# # Polymesher

# %% [markdown]
# **Reference**: Talischi, C., Paulino, G.H., Pereira, A. et al. PolyMesher: a general-purpose mesh generator for polygonal elements written in Matlab. Struct Multidisc Optim 45, 309–328 (2012). https://doi.org/10.1007/s00158-011-0706-z

# %%
from optymus.methods import polymesher
from optymus.benchmark import (
    MbbDomain,
    HornDomain,
    CookDomain,
    WrenchDomain,
    MichellDomain,
    SuspensionDomain,
)

# %%
MbbDomain.plot()

# %%
horn = polymesher(domain=HornDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 227.82step/s, Error=0.00167, Iteration=100, Time=0.387]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 159.75step/s, Error=0.00167, Iteration=100, Time=0.387]

# %%
mbb = polymesher(domain=MbbDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 249.82step/s, Error=0.00379, Iteration=100, Time=0.415]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 150.62step/s, Error=0.00379, Iteration=100, Time=0.415]

# %%
cook = polymesher(domain=CookDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 143.85step/s, Error=0.00316, Iteration=100, Time=0.58]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 120.18step/s, Error=0.00316, Iteration=100, Time=0.58]

# %%
wrench = polymesher(domain=WrenchDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 183.50step/s, Error=0.00249, Iteration=100, Time=0.53]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 127.72step/s, Error=0.00249, Iteration=100, Time=0.53]

# %%
michell = polymesher(domain=MichellDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 206.58step/s, Error=0.00309, Iteration=100, Time=0.436]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 145.39step/s, Error=0.00309, Iteration=100, Time=0.436]

# %%
suspension = polymesher(domain=SuspensionDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 154.61step/s, Error=0.00277, Iteration=100, Time=0.612]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 107.43step/s, Error=0.00277, Iteration=100, Time=0.612]
