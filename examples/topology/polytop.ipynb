# %%
from optymus.methods import polytop, polymesher
from optymus.benchmark import HornDomain

# %%
horn = polymesher(domain=HornDomain, n_elements=1000, max_iter=100, plot=False)
# Out:
# Iterations: 100%|██████████| 100/100 [00:03<00:00, 28.88step/s, Error=0.00274, Iteration=100, Time=3.27]

# %%
z, x, y = polytop(horn, opt)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 z, x, y = polytop(horn, opt)
#
# File ~/repos/research/optymus/src/optymus/methods/topological/_polytop.py:14, in polytop(fem, opt)
#      11 p = opt['p']
#      13 e, de_dy, v, dv_dy = opt['mat_int_fnc'](np.dot(p, z))
# ---> 14 fig_handle, fig_data = initial_plot(fem, v)
#      16 while (iter < opt['max_iter']) and (change > tol):
#      17     iter += 1
#
# File ~/repos/research/optymus/src/optymus/methods/topological/_polytop.py:248, in initial_plot(fem, z0)
#     245 map_data = np.array(map_data)
#     247 fig, ax = plt.subplots()
# --> 248 handle = ax.tripcolor(fem['node'][:, 0], fem['node'][:, 1], tri, 1 - z0[map_data],
#     249                       shading='flat', cmap='gray')
#     250 ax.set_aspect('equal')
#     251 ax.axis('off')
#
# IndexError: invalid index to scalar variable.
