# %%
import sys
sys.path.append('../')

import warnings
warnings.filterwarnings('ignore')

import numpy as np
from optymus.minimize import Optimizer

# %%
f = lambda x: x[0]**[2]-3*x[0]*x[1]+4*x[1]**2+x[0]-x[1]
grad = lambda x: np.array([2*x[0]-3*x[1]+1, -3*x[0]+8*x[1]-1])
hess = lambda x: np.array([[2, -3], [-3, 8]])

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z = f([X, Y])

initial_point = np.array([2,2])

# %%
optimizer = Optimizer(f_obj=f,
                      x0=initial_point,
                      grad=grad,
                      hess=hess,
                      method='bfgs')

# %%
optimizer.report()
# Out:
# Method: BFGS
# Minimum: [-0.28571429]
# Number of iterations: 28
# Optimal point: [-0.71426933 -0.14284423]

# %%
optimizer.plot()
