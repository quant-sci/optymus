# %%
import sys
sys.path.append('../')

import jax.numpy as jnp
from optymus.optim import Optimizer
from optymus.utils import sphere_function

# %%
f = sphere_function()
initial_point = jnp.array([2.0, 2.0])

# %%
optimizer = Optimizer(f_obj=f,
                      x0=initial_point,
                      method='univariant',
                      )

# %%
optimizer.report()
# Out:
# --------------------
# Method Name: Univariant
# --------------------
# --------------------
# Results
# --------------------
# Initial point: [2. 2.]
# Minimum: 9.79237088655588e-19
# Number of iterations: 1
# Optimal point: [-9.895302e-10 -8.185452e-12]
# --------------------

# %%
optimizer.plot(print_opt=False)
