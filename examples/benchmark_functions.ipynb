# %%
import sys
sys.path.append('../')

# %%
from optymus.utils import plot_function, styblinski_tang_function

f = styblinski_tang_function()
plot_function(f, title='Styblinski Function', min=-5.12, max=5.12)
