# %% [markdown]
# # Polymesher

# %% [markdown]
# **Reference**: Talischi, C., Paulino, G.H., Pereira, A. et al. PolyMesher: a general-purpose mesh generator for polygonal elements written in Matlab. Struct Multidisc Optim 45, 309–328 (2012). https://doi.org/10.1007/s00158-011-0706-z

# %%
from optymus.methods.topological import polymesher
from optymus.benchmark import (
    MbbDomain,
    HornDomain,
    CookDomain,
    WrenchDomain,
    MichellDomain,
    SuspensionDomain
)

# %%
MbbDomain.plot()

# %%
horn = polymesher(domain=HornDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 185.64step/s, Error=0.00272, Iteration=100, Time=0.511]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 121.45step/s, Error=0.00272, Iteration=100, Time=0.511]

# %%
mbb = polymesher(domain=MbbDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 213.33step/s, Error=0.00155, Iteration=100, Time=0.42]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 155.33step/s, Error=0.00155, Iteration=100, Time=0.42]

# %%
cook = polymesher(domain=CookDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 193.65step/s, Error=0.00511, Iteration=100, Time=0.45]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 140.63step/s, Error=0.00511, Iteration=100, Time=0.45]

# %%
wrench = polymesher(domain=WrenchDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 146.81step/s, Error=0.00318, Iteration=100, Time=0.557]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 126.06step/s, Error=0.00318, Iteration=100, Time=0.557]

# %%
michell = polymesher(domain=MichellDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 213.30step/s, Error=0.00197, Iteration=100, Time=0.412]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 150.76step/s, Error=0.00197, Iteration=100, Time=0.412]

# %%
suspension = polymesher(domain=SuspensionDomain, n_elements=100, max_iter=100)
# Out:
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 172.70step/s, Error=0.00295, Iteration=100, Time=0.514]
# Iterations: 100%|██████████| 100/100 [00:00<00:00, 124.80step/s, Error=0.00295, Iteration=100, Time=0.514]
