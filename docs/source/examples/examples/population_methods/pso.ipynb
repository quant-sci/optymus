# %%
from optymus.benchmark import Ackley
from optymus.methods import particle_swarm

# %%
f = Ackley()
f_bounds = f.BOUNDS

result = particle_swarm(
    f_obj=f, 
    max_iter=50,
    verbose=True,
    bounds=f_bounds,
    visualize=True
)
# Out:
# Particle Swarm Optimization: 100%|██████████| 50/50 [00:04<00:00, 10.53it/s]
# Animation saved as pso_animation.mp4
